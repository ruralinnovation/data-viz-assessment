# %%
library(ggplot2)
library(tidycensus)
library(tidyverse)
library(tigris)
library(sf)
library(dplyr)
library(viridis)
options(tigris_use_cache = TRUE)
# Being a cybersecure person and importing my API key from an ignored file
census_api_key(readChar("api_key.txt",file.info("api_key.txt")$size))
# Out:
# ── Attaching core tidyverse packages ─────────────────────────────────────────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ lubridate 1.9.4     ✔ tibble    3.2.1
# ✔ purrr     1.0.4     ✔ tidyr     1.3.1
# ── Conflicts ───────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# To enable caching of data, set `options(tigris_use_cache = TRUE)`
# in your R script or .Rprofile.
#
# Linking to GEOS 3.13.0, GDAL 3.10.0, PROJ 9.5.1; sf_use_s2() is TRUE
#
# Loading required package: viridisLite
#
# To install your API key for use in future sessions, run this function with `install = TRUE`.

# %%
library(devtools)
# Bringing in the plotting style
devtools::install_github("ruralinnovation/cori.charts")
library(cori.charts)
cori.charts::load_fonts()
# Out:
# Loading required package: usethis
#
# Skipping install of 'cori.charts' from a github remote, the SHA1 (8a1f5d6c) has not changed since last install.
#   Use `force = TRUE` to force installation

# %% [markdown]
# ## Importing and processing the data

# %%
# Definitions of rural/nonrural can be fuzzy, we'll use CBSA
rural_defs <- read_csv("../data/cbsa_2020.csv")
rural_defs$GEOID = rural_defs$geoid # creating an uppercase for merging consistency
# B28002_007 = "Has a broadband internet subscription"
# B28002_001 = "Total households"
# "geometry = TRUE" pulls in the county shapes from tigris, allowing us to skip an additional merge.
# county <- get_acs(geography = "county", variables = c("B28002_001","B28002_007"), geometry = TRUE, year = 2023)

# county <- county %>% shift_geometry()
# county <- st_transform(county, crs=5070)
# st_write(county,'../data/counties-broadband-shape.shp',append=FALSE)
county <- st_read('../data/counties-broadband-shape.shp')
# county %>% filter(grepl('Conn', NAME))
# Out:
# Rows: 3234 Columns: 5
# ── Column specification ───────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (4): geoid, name, rural_def, is_rural
# dbl (1): year
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Reading layer `counties-broadband-shape' from data source
#   `/Users/benemery/cori/assessment/data/counties-broadband-shape.shp'
#   using driver `ESRI Shapefile'
# Simple feature collection with 6444 features and 5 fields
# Geometry type: MULTIPOLYGON
# Dimension:     XY
# Bounding box:  xmin: -3111747 ymin: -90959.31 xmax: 2258200 ymax: 3172568
# Projected CRS: NAD83 / Conus Albers

# %%
# Loading multiple variables automatically formats them as long-form, creating multiple rows
# for each county. We pivot the data frame to wide-form so each county gets one row, and
# each variable has its own column.
county <- county %>%
  pivot_wider(names_from = variable, values_from = c(estimate,moe),values_fill = 0)


# Renaming columns for humans who don't memorize serial numbers.
colnames(county)[4] <- "households_est"
colnames(county)[5] <- "broadband_est"
colnames(county)[6] <- "households_moe"
colnames(county)[7] <- "broadband_moe"
# Create a new column that contains the amount of broadband access 
# expressed as a fraction of the total number of households.
county$broadband_frac = county$broadband_est/county$households_est


# The rural definitions seem to have Connecticut missing, so we'll need to rename the 
# merged df, and access the original later.
county_rurality <- merge(county, rural_defs[c('is_rural','GEOID')], by='GEOID')

# %% [markdown]
# ## Generating plots
# ### 1. A simple plot comparing the two county categories

# %%
# f<-ggplot(county, aes(is_rural,broadband_frac, fill=is_rural)) + #Uncomment to save figure
ggplot(county_rurality, aes(is_rural,broadband_frac, fill=is_rural)) +
    geom_violin(trim=FALSE)+
    geom_boxplot(width=0.1,outliers=FALSE)+
    theme_cori()+
    theme(legend.position="none")+
    scale_fill_cori(palette = "ctg2tlpu", reverse = TRUE)+
    labs(title = "Fraction of households with broadband access",
       subtitle = "By rurality",
       x = NULL,
       y = NULL,
       caption = "Source: US Census ACS")
# save_plot(f,"../export/broadband-violins.png",chart_width=6,chart_height=7,add_logo=FALSE) #Uncomment to save figure
# Out:
# plot without title

# %% [markdown]
# As one would reasonably expect, rural counties, on average, have less broadband access. While the distributions do overlap substantially, it's notable that the rural median is close to the nonrural first quartile. The nonrural median fraction appears to by around 0.7, while the rural median fraction is closer to 0.6. By virtue of the distributional center being closer to the midpoint of the physical bounds, the rural distribution is closer to symmetric, while they both have some skew, with the longer tail extending into the lower values.

# %% [markdown]
# ### A map of all the counties and their fractional broadband access
# The following cell has all the lines commented out, because internet problems were preventing me from repeatedly running the `st_transform()` function. I instead exported the transformed shapefile after getting it to work and simply loaded it locally any time it was subsequently necessary.

# %%
# The geometry is already there for us from the geometry = True tag earlier.

# But, we still need to rearrange the noncontiguous parts and specify the projection.
# county <- county %>% shift_geometry()
# county <- st_transform(county, crs=5070)
# st_write(county,'../data/counties-broadband-shape.shp',append=FALSE)

# %%
# f <- ggplot(data=county)+
ggplot(data=county)+
      geom_sf(data = county, fill = NA, color = "gray80", size = 0.1) +
      geom_sf(
        data = filter(county), #is_rural == "Rural"), #If only plotting rural counties
        aes(fill = broadband_frac),
        color = NA
      ) +
    scale_fill_viridis(name = "fraction with access", na.value = "grey90") +
    labs(title = "Fraction of households with broadband",
        subtitle = "By county",
        caption = "Source: US Census ACS")+
    theme_cori_map()
# save_plot(f,"../export/broadband-2.png",chart_width=9,chart_height=7)
# Out:
# plot without title

# %% [markdown]
# This is a rich visualization with more to be learned than I can process in this short time. The pieces that I notice will surely be a reflection of my personal and intellectual interests.
#
# First, the northeast stands out as a region with anomolously extensive broadband access, especially in the band spanning from Massachussetts to DC. There's also a noticeable cluster of low access around Arkansas, Louisiana, Mississippi, and Alabama. Predictably, large portions of northern Alaska have virtually nonexistent broadband access. Access is also notably low in Puerto Rico, southern Virginia, the dividing line between Oregon/Idaho and California/Nevada, and on the northern half of the Arizona - New Mexico border.

# %%
library(rmarkdown)
convert_ipynb('county_broadband.ipynb','county_broadband.rmd')

# %%
rmarkdown::render("county_broadband.rmd", "html_document")
# Out:
# processing file: county_broadband.rmd
# 1/19
# 2/19 [unnamed-chunk-1]
# 3/19
# 4/19 [unnamed-chunk-2]
# 5/19
# 6/19 [unnamed-chunk-3]
# 7/19
# 8/19 [unnamed-chunk-4]
# 9/19
# 10/19 [unnamed-chunk-5]
# 11/19
# 12/19 [unnamed-chunk-6]
# 13/19
# 14/19 [unnamed-chunk-7]
# 15/19
# 16/19 [unnamed-chunk-8]
# 17/19
# 18/19 [unnamed-chunk-9]
# Error in `sink()`:
# ! sink stack is full
# Traceback:
#
# 1. knitr::knit(knit_input, knit_output, envir = envir, quiet = quiet)
# 2. process_file(text, output)
# 3. xfun:::handle_error(withCallingHandlers(if (tangle) process_tangle(group) else process_group(group),
#  .     error = function(e) {
#  .         if (progress && is.function(pb$interrupt))
#  .             pb$interrupt()
#  .         if (xfun::pkg_available("rlang", "1.0.0")) {
#  .             if (is_R_CMD_build() || is_R_CMD_check()) {
#  .                 cnd = tryCatch(rlang::entrace(e), error = identity)
#  .                 error <<- format(cnd)
#  .             }
#  .             else {
#  .                 rlang::entrace(e)
#  .             }
#  .         }
#  .     }), function(loc) {
#  .     setwd(wd)
#  .     write_utf8(res, output %n% stdout())
#  .     paste0("\nQuitting from ", loc, if (!is.null(error))
#  .         paste0("\n", rule(), error, "\n", rule()))
#  . }, if (labels[i] != "") sprintf(" [%s]", labels[i]), get_loc)
# 4. withCallingHandlers(if (tangle) process_tangle(group) else process_group(group),
#  .     error = function(e) {
#  .         if (progress && is.function(pb$interrupt))
#  .             pb$interrupt()
#  .         if (xfun::pkg_available("rlang", "1.0.0")) {
#  .             if (is_R_CMD_build() || is_R_CMD_check()) {
#  .                 cnd = tryCatch(rlang::entrace(e), error = identity)
#  .                 error <<- format(cnd)
#  .             }
#  .             else {
#  .                 rlang::entrace(e)
#  .             }
#  .         }
#  .     })
# 5. process_group(group)
# 6. call_block(x)
# 7. block_exec(params)
# 8. eng_r(options)
# 9. in_input_dir(evaluate(code, envir = env, new_device = FALSE,
#  .     keep_warning = if (is.numeric(options$warning)) TRUE else options$warning,
#  .     keep_message = if (is.numeric(options$message)) TRUE else options$message,
#  .     stop_on_error = if (is.numeric(options$error)) options$error else {
#  .         if (options$error && options$include)
#  .             0L
#  .         else 2L
#  .     }, output_handler = knit_handlers(options$render, options)))
# 10. in_dir(input_dir(), expr)
# 11. evaluate(code, envir = env, new_device = FALSE, keep_warning = if (is.numeric(options$warning)) TRUE else options$warning,
#   .     keep_message = if (is.numeric(options$message)) TRUE else options$message,
#   .     stop_on_error = if (is.numeric(options$error)) options$error else {
#   .         if (options$error && options$include)
#   .             0L
#   .         else 2L
#   .     }, output_handler = knit_handlers(options$render, options))
# 12. evaluate::evaluate(...)
# 13. withRestarts(with_handlers({
#   .     for (expr in tle$exprs) {
#   .         ev <- withVisible(eval(expr, envir))
#   .         watcher$capture_plot_and_output()
#   .         watcher$print_value(ev$value, ev$visible, envir)
#   .     }
#   .     TRUE
#   . }, handlers), eval_continue = function() TRUE, eval_stop = function() FALSE)
# 14. withRestartList(expr, restarts)
# 15. withOneRestart(withRestartList(expr, restarts[-nr]), restarts[[nr]])
# 16. doWithOneRestart(return(expr), restart)
# 17. withRestartList(expr, restarts[-nr])
# 18. withOneRestart(expr, restarts[[1L]])
# 19. doWithOneRestart(return(expr), restart)
# 20. with_handlers({
#   .     for (expr in tle$exprs) {
#   .         ev <- withVisible(eval(expr, envir))
#   .         watcher$capture_plot_and_output()
#   .         watcher$print_value(ev$value, ev$visible, envir)
#   .     }
#   .     TRUE
#   . }, handlers)
# 21. eval(call)
# 22. eval(call)
# 23. withCallingHandlers(code, message = function (cnd)
#   . {
#   .     watcher$capture_plot_and_output()
#   .     if (on_message$capture) {
#   .         watcher$push(cnd)
#   .     }
#   .     if (on_message$silence) {
#   .         invokeRestart("muffleMessage")
#   .     }
#   . }, warning = function (cnd)
#   . {
#   .     if (getOption("warn") >= 2 || getOption("warn") < 0) {
#   .         return()
#   .     }
#   .     watcher$capture_plot_and_output()
#   .     if (on_warning$capture) {
#   .         cnd <- sanitize_call(cnd)
#   .         watcher$push(cnd)
#   .     }
#   .     if (on_warning$silence) {
#   .         invokeRestart("muffleWarning")
#   .     }
#   . }, error = function (cnd)
#   . {
#   .     watcher$capture_plot_and_output()
#   .     cnd <- sanitize_call(cnd)
#   .     watcher$push(cnd)
#   .     switch(on_error, continue = invokeRestart("eval_continue"),
#   .         stop = invokeRestart("eval_stop"), error = NULL)
#   . })
# 24. withVisible(eval(expr, envir))
# 25. eval(expr, envir)
# 26. eval(expr, envir)
# 27. rmarkdown::render("county_broadband.rmd", "html_document")
# 28. knitr::knit(knit_input, knit_output, envir = envir, quiet = quiet)
# 29. process_file(text, output)
# 30. xfun:::handle_error(withCallingHandlers(if (tangle) process_tangle(group) else process_group(group),
#   .     error = function(e) {
#   .         if (progress && is.function(pb$interrupt))
#   .             pb$interrupt()
#   .         if (xfun::pkg_available("rlang", "1.0.0")) {
#   .             if (is_R_CMD_build() || is_R_CMD_check()) {
#   .                 cnd = tryCatch(rlang::entrace(e), error = identity)
#   .                 error <<- format(cnd)
#   .             }
#   .             else {
#   .                 rlang::entrace(e)
#   .             }
#   .         }
#   .     }), function(loc) {
#   .     setwd(wd)
#   .     write_utf8(res, output %n% stdout())
#   .     paste0("\nQuitting from ", loc, if (!is.null(error))
#   .         paste0("\n", rule(), error, "\n", rule()))
#   . }, if (labels[i] != "") sprintf(" [%s]", labels[i]), get_loc)
# 31. withCallingHandlers(if (tangle) process_tangle(group) else process_group(group),
#   .     error = function(e) {
#   .         if (progress && is.function(pb$interrupt))
#   .             pb$interrupt()
#   .         if (xfun::pkg_available("rlang", "1.0.0")) {
#   .             if (is_R_CMD_build() || is_R_CMD_check()) {
#   .                 cnd = tryCatch(rlang::entrace(e), error = identity)
#   .                 error <<- format(cnd)
#   .             }
#   .             else {
#   .                 rlang::entrace(e)
#   .             }
#   .         }
#   .     })
# 32. process_group(group)
# 33. call_block(x)
# 34. block_exec(params)
# 35. eng_r(options)
# 36. in_input_dir(evaluate(code, envir = env, new_device = FALSE,
#   .     keep_warning = if (is.numeric(options$warning)) TRUE else options$warning,
#   .     keep_message = if (is.numeric(options$message)) TRUE else options$message,
#   .     stop_on_error = if (is.numeric(options$error)) options$error else {
#   .         if (options$error && options$include)
#   .             0L
#   .         else 2L
#   .     }, output_handler = knit_handlers(options$render, options)))
# 37. in_dir(input_dir(), expr)
# 38. evaluate(code, envir = env, new_device = FALSE, keep_warning = if (is.numeric(options$warning)) TRUE else options$warning,
#   .     keep_message = if (is.numeric(options$message)) TRUE else options$message,
#   .     stop_on_error = if (is.numeric(options$error)) options$error else {
#   .         if (options$error && options$include)
#   .             0L
#   .         else 2L
#   .     }, output_handler = knit_handlers(options$render, options))
# 39. evaluate::evaluate(...)
# 40. withRestarts(with_handlers({
#   .     for (expr in tle$exprs) {
#   .         ev <- withVisible(eval(expr, envir))
#   .         watcher$capture_plot_and_output()
#   .         watcher$print_value(ev$value, ev$visible, envir)
#   .     }
#   .     TRUE
#   . }, handlers), eval_continue = function() TRUE, eval_stop = function() FALSE)
# 41. withRestartList(expr, restarts)
# 42. withOneRestart(withRestartList(expr, restarts[-nr]), restarts[[nr]])
# 43. doWithOneRestart(return(expr), restart)
# 44. withRestartList(expr, restarts[-nr])
# 45. withOneRestart(expr, restarts[[1L]])
# 46. doWithOneRestart(return(expr), restart)
# 47. with_handlers({
#   .     for (expr in tle$exprs) {
#   .         ev <- withVisible(eval(expr, envir))
#   .         watcher$capture_plot_and_output()
#   .         watcher$print_value(ev$value, ev$visible, envir)
#   .     }
#   .     TRUE
#   . }, handlers)
# 48. eval(call)
# 49. eval(call)
# 50. withCallingHandlers(code, message = function (cnd)
#   . {
#   .     watcher$capture_plot_and_output()
#   .     if (on_message$capture) {
#   .         watcher$push(cnd)
#   .     }
#   .     if (on_message$silence) {
#   .         invokeRestart("muffleMessage")
#   .     }
#   . }, warning = function (cnd)
#   . {
#   .     if (getOption("warn") >= 2 || getOption("warn") < 0) {
#   .         return()
#   .     }
#   .     watcher$capture_plot_and_output()
#   .     if (on_warning$capture) {
#   .         cnd <- sanitize_call(cnd)
#   .         watcher$push(cnd)
#   .     }
#   .     if (on_warning$silence) {
#   .         invokeRestart("muffleWarning")
#   .     }
#   . }, error = function (cnd)
#   . {
#   .     watcher$capture_plot_and_output()
#   .     cnd <- sanitize_call(cnd)
#   .     watcher$push(cnd)
#   .     switch(on_error, continue = invokeRestart("eval_continue"),
#   .         stop = invokeRestart("eval_stop"), error = NULL)
#   . })
# 51. withVisible(eval(expr, envir))
# 52. eval(expr, envir)
# 53. eval(expr, envir)
# 54. rmarkdown::render("county_broadband.rmd", "html_document")
# 55. knitr::knit(knit_input, knit_output, envir = envir, quiet = quiet)
# 56. process_file(text, output)
# 57. xfun:::handle_error(withCallingHandlers(if (tangle) process_tangle(group) else process_group(group),
#   .     error = function(e) {
#   .         if (progress && is.function(pb$interrupt))
#   .             pb$interrupt()
#   .         if (xfun::pkg_available("rlang", "1.0.0")) {
#   .             if (is_R_CMD_build() || is_R_CMD_check()) {
#   .                 cnd = tryCatch(rlang::entrace(e), error = identity)
#   .                 error <<- format(cnd)
#   .             }
#   .             else {
#   .                 rlang::entrace(e)
#   .             }
#   .         }
#   .     }), function(loc) {
#   .     setwd(wd)
#   .     write_utf8(res, output %n% stdout())
#   .     paste0("\nQuitting from ", loc, if (!is.null(error))
#   .         paste0("\n", rule(), error, "\n", rule()))
#   . }, if (labels[i] != "") sprintf(" [%s]", labels[i]), get_loc)
# 58. withCallingHandlers(if (tangle) process_tangle(group) else process_group(group),
#   .     error = function(e) {
#   .         if (progress && is.function(pb$interrupt))
#   .             pb$interrupt()
#   .         if (xfun::pkg_available("rlang", "1.0.0")) {
#   .             if (is_R_CMD_build() || is_R_CMD_check()) {
#   .                 cnd = tryCatch(rlang::entrace(e), error = identity)
#   .                 error <<- format(cnd)
#   .             }
#   .             else {
#   .                 rlang::entrace(e)
#   .             }
#   .         }
#   .     })
# 59. process_group(group)
# 60. call_block(x)
# 61. block_exec(params)
# 62. eng_r(options)
# 63. in_input_dir(evaluate(code, envir = env, new_device = FALSE,
#   .     keep_warning = if (is.numeric(options$warning)) TRUE else options$warning,
#   .     keep_message = if (is.numeric(options$message)) TRUE else options$message,
#   .     stop_on_error = if (is.numeric(options$error)) options$error else {
#   .         if (options$error && options$include)
#   .             0L
#   .         else 2L
#   .     }, output_handler = knit_handlers(options$render, options)))
# 64. in_dir(input_dir(), expr)
# 65. evaluate(code, envir = env, new_device = FALSE, keep_warning = if (is.numeric(options$warning)) TRUE else options$warning,
#   .     keep_message = if (is.numeric(options$message)) TRUE else options$message,
#   .     stop_on_error = if (is.numeric(options$error)) options$error else {
#   .         if (options$error && options$include)
#   .             0L
#   .         else 2L
#   .     }, output_handler = knit_handlers(options$render, options))
# 66. evaluate::evaluate(...)
# 67. withRestarts(with_handlers({
#   .     for (expr in tle$exprs) {
#   .         ev <- withVisible(eval(expr, envir))
#   .         watcher$capture_plot_and_output()
#   .         watcher$print_value(ev$value, ev$visible, envir)
#   .     }
#   .     TRUE
#   . }, handlers), eval_continue = function() TRUE, eval_stop = function() FALSE)
# 68. withRestartList(expr, restarts)
# 69. withOneRestart(withRestartList(expr, restarts[-nr]), restarts[[nr]])
# 70. doWithOneRestart(return(expr), restart)
# 71. withRestartList(expr, restarts[-nr])
# 72. withOneRestart(expr, restarts[[1L]])
# 73. doWithOneRestart(return(expr), restart)
# 74. with_handlers({
#   .     for (expr in tle$exprs) {
#   .         ev <- withVisible(eval(expr, envir))
#   .         watcher$capture_plot_and_output()
#   .         watcher$print_value(ev$value, ev$visible, envir)
#   .     }
#   .     TRUE
#   . }, handlers)
# 75. eval(call)
# 76. eval(call)
# 77. withCallingHandlers(code, message = function (cnd)
#   . {
#   .     watcher$capture_plot_and_output()
#   .     if (on_message$capture) {
#   .         watcher$push(cnd)
#   .     }
#   .     if (on_message$silence) {
#   .         invokeRestart("muffleMessage")
#   .     }
#   . }, warning = function (cnd)
#   . {
#   .     if (getOption("warn") >= 2 || getOption("warn") < 0) {
#   .         return()
#   .     }
#   .     watcher$capture_plot_and_output()
#   .     if (on_warning$capture) {
#   .         cnd <- sanitize_call(cnd)
#   .         watcher$push(cnd)
#   .     }
#   .     if (on_warning$silence) {
#   .         invokeRestart("muffleWarning")
#   .     }
#   . }, error = function (cnd)
#   . {
#   .     watcher$capture_plot_and_output()
#   .     cnd <- sanitize_call(cnd)
#   .     watcher$push(cnd)
#   .     switch(on_error, continue = invokeRestart("eval_continue"),
#   .         stop = invokeRestart("eval_stop"), error = NULL)
#   . })
# 78. withVisible(eval(expr, envir))
# 79. eval(expr, envir)
# 80. eval(expr, envir)
# 81. rmarkdown::render("county_broadband.rmd", "html_document")
# 82. knitr::knit(knit_input, knit_output, envir = envir, quiet = quiet)
# 83. process_file(text, output)
# 84. xfun:::handle_error(withCallingHandlers(if (tangle) process_tangle(group) else process_group(group),
#   .     error = function(e) {
#   .         if (progress && is.function(pb$interrupt))
#   .             pb$interrupt()
#   .         if (xfun::pkg_available("rlang", "1.0.0")) {
#   .             if (is_R_CMD_build() || is_R_CMD_check()) {
#   .                 cnd = tryCatch(rlang::entrace(e), error = identity)
#   .                 error <<- format(cnd)
#   .             }
#   .             else {
#   .                 rlang::entrace(e)
#   .             }
#   .         }
#   .     }), function(loc) {
#   .     setwd(wd)
#   .     write_utf8(res, output %n% stdout())
#   .     paste0("\nQuitting from ", loc, if (!is.null(error))
#   .         paste0("\n", rule(), error, "\n", rule()))
#   . }, if (labels[i] != "") sprintf(" [%s]", labels[i]), get_loc)
# 85. withCallingHandlers(if (tangle) process_tangle(group) else process_group(group),
#   .     error = function(e) {
#   .         if (progress && is.function(pb$interrupt))
#   .             pb$interrupt()
#   .         if (xfun::pkg_available("rlang", "1.0.0")) {
#   .             if (is_R_CMD_build() || is_R_CMD_check()) {
#   .                 cnd = tryCatch(rlang::entrace(e), error = identity)
#   .                 error <<- format(cnd)
#   .             }
#   .             else {
#   .                 rlang::entrace(e)
#   .             }
#   .         }
#   .     })
# 86. process_group(group)
# 87. call_block(x)
# 88. block_exec(params)
# 89. eng_r(options)
# 90. in_input_dir(evaluate(code, envir = env, new_device = FALSE,
#   .     keep_warning = if (is.numeric(options$warning)) TRUE else options$warning,
#   .     keep_message = if (is.numeric(options$message)) TRUE else options$message,
#   .     stop_on_error = if (is.numeric(options$error)) options$error else {
#   .         if (options$error && options$include)
#   .             0L
#   .         else 2L
#   .     }, output_handler = knit_handlers(options$render, options)))
# 91. in_dir(input_dir(), expr)
# 92. evaluate(code, envir = env, new_device = FALSE, keep_warning = if (is.numeric(options$warning)) TRUE else options$warning,
#   .     keep_message = if (is.numeric(options$message)) TRUE else options$message,
#   .     stop_on_error = if (is.numeric(options$error)) options$error else {
#   .         if (options$error && options$include)
#   .             0L
#   .         else 2L
#   .     }, output_handler = knit_handlers(options$render, options))
# 93. evaluate::evaluate(...)
# 94. withRestarts(with_handlers({
#   .     for (expr in tle$exprs) {
#   .         ev <- withVisible(eval(expr, envir))
#   .         watcher$capture_plot_and_output()
#   .         watcher$print_value(ev$value, ev$visible, envir)
#   .     }
#   .     TRUE
#   . }, handlers), eval_continue = function() TRUE, eval_stop = function() FALSE)
# 95. withRestartList(expr, restarts)
# 96. withOneRestart(withRestartList(expr, restarts[-nr]), restarts[[nr]])
# 97. doWithOneRestart(return(expr), restart)
# 98. withRestartList(expr, restarts[-nr])
# 99. withOneRestart(expr, restarts[[1L]])
# 100. doWithOneRestart(return(expr), restart)
# 101. with_handlers({
#    .     for (expr in tle$exprs) {
#    .         ev <- withVisible(eval(expr, envir))
#    .         watcher$capture_plot_and_output()
#    .         watcher$print_value(ev$value, ev$visible, envir)
#    .     }
#    .     TRUE
#    . }, handlers)
# 102. eval(call)
# 103. eval(call)
# 104. withCallingHandlers(code, message = function (cnd)
#    . {
#    .     watcher$capture_plot_and_output()
#    .     if (on_message$capture) {
#    .         watcher$push(cnd)
#    .     }
#    .     if (on_message$silence) {
#    .         invokeRestart("muffleMessage")
#    .     }
#    . }, warning = function (cnd)
#    . {
#    .     if (getOption("warn") >= 2 || getOption("warn") < 0) {
#    .         return()
#    .     }
#    .     watcher$capture_plot_and_output()
#    .     if (on_warning$capture) {
#    .         cnd <- sanitize_call(cnd)
#    .         watcher$push(cnd)
#    .     }
#    .     if (on_warning$silence) {
#    .         invokeRestart("muffleWarning")
#    .     }
#    . }, error = function (cnd)
#    . {
#    .     watcher$capture_plot_and_output()
#    .     cnd <- sanitize_call(cnd)
#    .     watcher$push(cnd)
#    .     switch(on_error, continue = invokeRestart("eval_continue"),
#    .         stop = invokeRestart("eval_stop"), error = NULL)
#    . })
# 105. withVisible(eval(expr, envir))
# 106. eval(expr, envir)
# 107. eval(expr, envir)
# 108. rmarkdown::render("county_broadband.rmd", "html_document")
# 109. knitr::knit(knit_input, knit_output, envir = envir, quiet = quiet)
# 110. process_file(text, output)
# 111. xfun:::handle_error(withCallingHandlers(if (tangle) process_tangle(group) else process_group(group),
#    .     error = function(e) {
#    .         if (progress && is.function(pb$interrupt))
#    .             pb$interrupt()
#    .         if (xfun::pkg_available("rlang", "1.0.0")) {
#    .             if (is_R_CMD_build() || is_R_CMD_check()) {
#    .                 cnd = tryCatch(rlang::entrace(e), error = identity)
#    .                 error <<- format(cnd)
#    .             }
#    .             else {
#    .                 rlang::entrace(e)
#    .             }
#    .         }
#    .     }), function(loc) {
#    .     setwd(wd)
#    .     write_utf8(res, output %n% stdout())
#    .     paste0("\nQuitting from ", loc, if (!is.null(error))
#    .         paste0("\n", rule(), error, "\n", rule()))
#    . }, if (labels[i] != "") sprintf(" [%s]", labels[i]), get_loc)
# 112. withCallingHandlers(if (tangle) process_tangle(group) else process_group(group),
#    .     error = function(e) {
#    .         if (progress && is.function(pb$interrupt))
#    .             pb$interrupt()
#    .         if (xfun::pkg_available("rlang", "1.0.0")) {
#    .             if (is_R_CMD_build() || is_R_CMD_check()) {
#    .                 cnd = tryCatch(rlang::entrace(e), error = identity)
#    .                 error <<- format(cnd)
#    .             }
#    .             else {
#    .                 rlang::entrace(e)
#    .             }
#    .         }
#    .     })
# 113. process_group(group)
# 114. call_block(x)
# 115. block_exec(params)
# 116. eng_r(options)
# 117. in_input_dir(evaluate(code, envir = env, new_device = FALSE,
#    .     keep_warning = if (is.numeric(options$warning)) TRUE else options$warning,
#    .     keep_message = if (is.numeric(options$message)) TRUE else options$message,
#    .     stop_on_error = if (is.numeric(options$error)) options$error else {
#    .         if (options$error && options$include)
#    .             0L
#    .         else 2L
#    .     }, output_handler = knit_handlers(options$render, options)))
# 118. in_dir(input_dir(), expr)
# 119. evaluate(code, envir = env, new_device = FALSE, keep_warning = if (is.numeric(options$warning)) TRUE else options$warning,
#    .     keep_message = if (is.numeric(options$message)) TRUE else options$message,
#    .     stop_on_error = if (is.numeric(options$error)) options$error else {
#    .         if (options$error && options$include)
#    .             0L
#    .         else 2L
#    .     }, output_handler = knit_handlers(options$render, options))
# 120. evaluate::evaluate(...)
# 121. withRestarts(with_handlers({
#    .     for (expr in tle$exprs) {
#    .         ev <- withVisible(eval(expr, envir))
#    .         watcher$capture_plot_and_output()
#    .         watcher$print_value(ev$value, ev$visible, envir)
#    .     }
#    .     TRUE
#    . }, handlers), eval_continue = function() TRUE, eval_stop = function() FALSE)
# 122. withRestartList(expr, restarts)
# 123. withOneRestart(withRestartList(expr, restarts[-nr]), restarts[[nr]])
# 124. doWithOneRestart(return(expr), restart)
# 125. withRestartList(expr, restarts[-nr])
# 126. withOneRestart(expr, restarts[[1L]])
# 127. doWithOneRestart(return(expr), restart)
# 128. with_handlers({
#    .     for (expr in tle$exprs) {
#    .         ev <- withVisible(eval(expr, envir))
#    .         watcher$capture_plot_and_output()
#    .         watcher$print_value(ev$value, ev$visible, envir)
#    .     }
#    .     TRUE
#    . }, handlers)
# 129. eval(call)
# 130. eval(call)
# 131. withCallingHandlers(code, message = function (cnd)
#    . {
#    .     watcher$capture_plot_and_output()
#    .     if (on_message$capture) {
#    .         watcher$push(cnd)
#    .     }
#    .     if (on_message$silence) {
#    .         invokeRestart("muffleMessage")
#    .     }
#    . }, warning = function (cnd)
#    . {
#    .     if (getOption("warn") >= 2 || getOption("warn") < 0) {
#    .         return()
#    .     }
#    .     watcher$capture_plot_and_output()
#    .     if (on_warning$capture) {
#    .         cnd <- sanitize_call(cnd)
#    .         watcher$push(cnd)
#    .     }
#    .     if (on_warning$silence) {
#    .         invokeRestart("muffleWarning")
#    .     }
#    . }, error = function (cnd)
#    . {
#    .     watcher$capture_plot_and_output()
#    .     cnd <- sanitize_call(cnd)
#    .     watcher$push(cnd)
#    .     switch(on_error, continue = invokeRestart("eval_continue"),
#    .         stop = invokeRestart("eval_stop"), error = NULL)
#    . })
# 132. withVisible(eval(expr, envir))
# 133. eval(expr, envir)
# 134. eval(expr, envir)
# 135. rmarkdown::render("county_broadband.rmd", "html_document")
# 136. knitr::knit(knit_input, knit_output, envir = envir, quiet = quiet)
# 137. process_file(text, output)
# 138. xfun:::handle_error(withCallingHandlers(if (tangle) process_tangle(group) else process_group(group),
#    .     error = function(e) {
#    .         if (progress && is.function(pb$interrupt))
#    .             pb$interrupt()
#    .         if (xfun::pkg_available("rlang", "1.0.0")) {
#    .             if (is_R_CMD_build() || is_R_CMD_check()) {
#    .                 cnd = tryCatch(rlang::entrace(e), error = identity)
#    .                 error <<- format(cnd)
#    .             }
#    .             else {
#    .                 rlang::entrace(e)
#    .             }
#    .         }
#    .     }), function(loc) {
#    .     setwd(wd)
#    .     write_utf8(res, output %n% stdout())
#    .     paste0("\nQuitting from ", loc, if (!is.null(error))
#    .         paste0("\n", rule(), error, "\n", rule()))
#    . }, if (labels[i] != "") sprintf(" [%s]", labels[i]), get_loc)
# 139. withCallingHandlers(if (tangle) process_tangle(group) else process_group(group),
#    .     error = function(e) {
#    .         if (progress && is.function(pb$interrupt))
#    .             pb$interrupt()
#    .         if (xfun::pkg_available("rlang", "1.0.0")) {
#    .             if (is_R_CMD_build() || is_R_CMD_check()) {
#    .                 cnd = tryCatch(rlang::entrace(e), error = identity)
#    .                 error <<- format(cnd)
#    .             }
#    .             else {
#    .                 rlang::entrace(e)
#    .             }
#    .         }
#    .     })
# 140. process_group(group)
# 141. call_block(x)
# 142. block_exec(params)
# 143. eng_r(options)
# 144. in_input_dir(evaluate(code, envir = env, new_device = FALSE,
#    .     keep_warning = if (is.numeric(options$warning)) TRUE else options$warning,
#    .     keep_message = if (is.numeric(options$message)) TRUE else options$message,
#    .     stop_on_error = if (is.numeric(options$error)) options$error else {
#    .         if (options$error && options$include)
#    .             0L
#    .         else 2L
#    .     }, output_handler = knit_handlers(options$render, options)))
# 145. in_dir(input_dir(), expr)
# 146. evaluate(code, envir = env, new_device = FALSE, keep_warning = if (is.numeric(options$warning)) TRUE else options$warning,
#    .     keep_message = if (is.numeric(options$message)) TRUE else options$message,
#    .     stop_on_error = if (is.numeric(options$error)) options$error else {
#    .         if (options$error && options$include)
#    .             0L
#    .         else 2L
#    .     }, output_handler = knit_handlers(options$render, options))
# 147. evaluate::evaluate(...)
# 148. withRestarts(with_handlers({
#    .     for (expr in tle$exprs) {
#    .         ev <- withVisible(eval(expr, envir))
#    .         watcher$capture_plot_and_output()
#    .         watcher$print_value(ev$value, ev$visible, envir)
#    .     }
#    .     TRUE
#    . }, handlers), eval_continue = function() TRUE, eval_stop = function() FALSE)
# 149. withRestartList(expr, restarts)
# 150. withOneRestart(withRestartList(expr, restarts[-nr]), restarts[[nr]])
# 151. doWithOneRestart(return(expr), restart)
# 152. withRestartList(expr, restarts[-nr])
# 153. withOneRestart(expr, restarts[[1L]])
# 154. doWithOneRestart(return(expr), restart)
# 155. with_handlers({
#    .     for (expr in tle$exprs) {
#    .         ev <- withVisible(eval(expr, envir))
#    .         watcher$capture_plot_and_output()
#    .         watcher$print_value(ev$value, ev$visible, envir)
#    .     }
#    .     TRUE
#    . }, handlers)
# 156. eval(call)
# 157. eval(call)
# 158. withCallingHandlers(code, message = function (cnd)
#    . {
#    .     watcher$capture_plot_and_output()
#    .     if (on_message$capture) {
#    .         watcher$push(cnd)
#    .     }
#    .     if (on_message$silence) {
#    .         invokeRestart("muffleMessage")
#    .     }
#    . }, warning = function (cnd)
#    . {
#    .     if (getOption("warn") >= 2 || getOption("warn") < 0) {
#    .         return()
#    .     }
#    .     watcher$capture_plot_and_output()
#    .     if (on_warning$capture) {
#    .         cnd <- sanitize_call(cnd)
#    .         watcher$push(cnd)
#    .     }
#    .     if (on_warning$silence) {
#    .         invokeRestart("muffleWarning")
#    .     }
#    . }, error = function (cnd)
#    . {
#    .     watcher$capture_plot_and_output()
#    .     cnd <- sanitize_call(cnd)
#    .     watcher$push(cnd)
#    .     switch(on_error, continue = invokeRestart("eval_continue"),
#    .         stop = invokeRestart("eval_stop"), error = NULL)
#    . })
# 159. withVisible(eval(expr, envir))
# 160. eval(expr, envir)
# 161. eval(expr, envir)
# 162. rmarkdown::render("county_broadband.rmd", "html_document")
# 163. knitr::knit(knit_input, knit_output, envir = envir, quiet = quiet)
# 164. process_file(text, output)
# 165. xfun:::handle_error(withCallingHandlers(if (tangle) process_tangle(group) else process_group(group),
#    .     error = function(e) {
#    .         if (progress && is.function(pb$interrupt))
#    .             pb$interrupt()
#    .         if (xfun::pkg_available("rlang", "1.0.0")) {
#    .             if (is_R_CMD_build() || is_R_CMD_check()) {
#    .                 cnd = tryCatch(rlang::entrace(e), error = identity)
#    .                 error <<- format(cnd)
#    .             }
#    .             else {
#    .                 rlang::entrace(e)
#    .             }
#    .         }
#    .     }), function(loc) {
#    .     setwd(wd)
#    .     write_utf8(res, output %n% stdout())
#    .     paste0("\nQuitting from ", loc, if (!is.null(error))
#    .         paste0("\n", rule(), error, "\n", rule()))
#    . }, if (labels[i] != "") sprintf(" [%s]", labels[i]), get_loc)
# 166. withCallingHandlers(if (tangle) process_tangle(group) else process_group(group),
#    .     error = function(e) {
#    .         if (progress && is.function(pb$interrupt))
#    .             pb$interrupt()
#    .         if (xfun::pkg_available("rlang", "1.0.0")) {
#    .             if (is_R_CMD_build() || is_R_CMD_check()) {
#    .                 cnd = tryCatch(rlang::entrace(e), error = identity)
#    .                 error <<- format(cnd)
#    .             }
#    .             else {
#    .                 rlang::entrace(e)
#    .             }
#    .         }
#    .     })
# 167. process_group(group)
# 168. call_block(x)
# 169. block_exec(params)
# 170. eng_r(options)
# 171. in_input_dir(evaluate(code, envir = env, new_device = FALSE,
#    .     keep_warning = if (is.numeric(options$warning)) TRUE else options$warning,
#    .     keep_message = if (is.numeric(options$message)) TRUE else options$message,
#    .     stop_on_error = if (is.numeric(options$error)) options$error else {
#    .         if (options$error && options$include)
#    .             0L
#    .         else 2L
#    .     }, output_handler = knit_handlers(options$render, options)))
# 172. in_dir(input_dir(), expr)
# 173. evaluate(code, envir = env, new_device = FALSE, keep_warning = if (is.numeric(options$warning)) TRUE else options$warning,
#    .     keep_message = if (is.numeric(options$message)) TRUE else options$message,
#    .     stop_on_error = if (is.numeric(options$error)) options$error else {
#    .         if (options$error && options$include)
#    .             0L
#    .         else 2L
#    .     }, output_handler = knit_handlers(options$render, options))
# 174. evaluate::evaluate(...)
# 175. withRestarts(with_handlers({
#    .     for (expr in tle$exprs) {
#    .         ev <- withVisible(eval(expr, envir))
#    .         watcher$capture_plot_and_output()
#    .         watcher$print_value(ev$value, ev$visible, envir)
#    .     }
#    .     TRUE
#    . }, handlers), eval_continue = function() TRUE, eval_stop = function() FALSE)
# 176. withRestartList(expr, restarts)
# 177. withOneRestart(withRestartList(expr, restarts[-nr]), restarts[[nr]])
# 178. doWithOneRestart(return(expr), restart)
# 179. withRestartList(expr, restarts[-nr])
# 180. withOneRestart(expr, restarts[[1L]])
# 181. doWithOneRestart(return(expr), restart)
# 182. with_handlers({
#    .     for (expr in tle$exprs) {
#    .         ev <- withVisible(eval(expr, envir))
#    .         watcher$capture_plot_and_output()
#    .         watcher$print_value(ev$value, ev$visible, envir)
#    .     }
#    .     TRUE
#    . }, handlers)
# 183. eval(call)
# 184. eval(call)
# 185. withCallingHandlers(code, message = function (cnd)
#    . {
#    .     watcher$capture_plot_and_output()
#    .     if (on_message$capture) {
#    .         watcher$push(cnd)
#    .     }
#    .     if (on_message$silence) {
#    .         invokeRestart("muffleMessage")
#    .     }
#    . }, warning = function (cnd)
#    . {
#    .     if (getOption("warn") >= 2 || getOption("warn") < 0) {
#    .         return()
#    .     }
#    .     watcher$capture_plot_and_output()
#    .     if (on_warning$capture) {
#    .         cnd <- sanitize_call(cnd)
#    .         watcher$push(cnd)
#    .     }
#    .     if (on_warning$silence) {
#    .         invokeRestart("muffleWarning")
#    .     }
#    . }, error = function (cnd)
#    . {
#    .     watcher$capture_plot_and_output()
#    .     cnd <- sanitize_call(cnd)
#    .     watcher$push(cnd)
#    .     switch(on_error, continue = invokeRestart("eval_continue"),
#    .         stop = invokeRestart("eval_stop"), error = NULL)
#    . })
# 186. withVisible(eval(expr, envir))
# 187. eval(expr, envir)
# 188. eval(expr, envir)
# 189. rmarkdown::render("county_broadband.rmd", "html_document")
# 190. knitr::knit(knit_input, knit_output, envir = envir, quiet = quiet)
# 191. process_file(text, output)
# 192. xfun:::handle_error(withCallingHandlers(if (tangle) process_tangle(group) else process_group(group),
#    .     error = function(e) {
#    .         if (progress && is.function(pb$interrupt))
#    .             pb$interrupt()
#    .         if (xfun::pkg_available("rlang", "1.0.0")) {
#    .             if (is_R_CMD_build() || is_R_CMD_check()) {
#    .                 cnd = tryCatch(rlang::entrace(e), error = identity)
#    .                 error <<- format(cnd)
#    .             }
#    .             else {
#    .                 rlang::entrace(e)
#    .             }
#    .         }
#    .     }), function(loc) {
#    .     setwd(wd)
#    .     write_utf8(res, output %n% stdout())
#    .     paste0("\nQuitting from ", loc, if (!is.null(error))
#    .         paste0("\n", rule(), error, "\n", rule()))
#    . }, if (labels[i] != "") sprintf(" [%s]", labels[i]), get_loc)
# 193. withCallingHandlers(if (tangle) process_tangle(group) else process_group(group),
#    .     error = function(e) {
#    .         if (progress && is.function(pb$interrupt))
#    .             pb$interrupt()
#    .         if (xfun::pkg_available("rlang", "1.0.0")) {
#    .             if (is_R_CMD_build() || is_R_CMD_check()) {
#    .                 cnd = tryCatch(rlang::entrace(e), error = identity)
#    .                 error <<- format(cnd)
#    .             }
#    .             else {
#    .                 rlang::entrace(e)
#    .             }
#    .         }
#    .     })
# 194. process_group(group)
# 195. call_block(x)
# 196. block_exec(params)
# 197. eng_r(options)
# 198. in_input_dir(evaluate(code, envir = env, new_device = FALSE,
#    .     keep_warning = if (is.numeric(options$warning)) TRUE else options$warning,
#    .     keep_message = if (is.numeric(options$message)) TRUE else options$message,
#    .     stop_on_error = if (is.numeric(options$error)) options$error else {
#    .         if (options$error && options$include)
#    .             0L
#    .         else 2L
#    .     }, output_handler = knit_handlers(options$render, options)))
# 199. in_dir(input_dir(), expr)
# 200. evaluate(code, envir = env, new_device = FALSE, keep_warning = if (is.numeric(options$warning)) TRUE else options$warning,
#    .     keep_message = if (is.numeric(options$message)) TRUE else options$message,
#    .     stop_on_error = if (is.numeric(options$error)) options$error else {
#    .         if (options$error && options$include)
#    .             0L
#    .         else 2L
#    .     }, output_handler = knit_handlers(options$render, options))
# 201. evaluate::evaluate(...)
# 202. withRestarts(with_handlers({
#    .     for (expr in tle$exprs) {
#    .         ev <- withVisible(eval(expr, envir))
#    .         watcher$capture_plot_and_output()
#    .         watcher$print_value(ev$value, ev$visible, envir)
#    .     }
#    .     TRUE
#    . }, handlers), eval_continue = function() TRUE, eval_stop = function() FALSE)
# 203. withRestartList(expr, restarts)
# 204. withOneRestart(withRestartList(expr, restarts[-nr]), restarts[[nr]])
# 205. doWithOneRestart(return(expr), restart)
# 206. withRestartList(expr, restarts[-nr])
# 207. withOneRestart(expr, restarts[[1L]])
# 208. doWithOneRestart(return(expr), restart)
# 209. with_handlers({
#    .     for (expr in tle$exprs) {
#    .         ev <- withVisible(eval(expr, envir))
#    .         watcher$capture_plot_and_output()
#    .         watcher$print_value(ev$value, ev$visible, envir)
#    .     }
#    .     TRUE
#    . }, handlers)
# 210. eval(call)
# 211. eval(call)
# 212. withCallingHandlers(code, message = function (cnd)
#    . {
#    .     watcher$capture_plot_and_output()
#    .     if (on_message$capture) {
#    .         watcher$push(cnd)
#    .     }
#    .     if (on_message$silence) {
#    .         invokeRestart("muffleMessage")
#    .     }
#    . }, warning = function (cnd)
#    . {
#    .     if (getOption("warn") >= 2 || getOption("warn") < 0) {
#    .         return()
#    .     }
#    .     watcher$capture_plot_and_output()
#    .     if (on_warning$capture) {
#    .         cnd <- sanitize_call(cnd)
#    .         watcher$push(cnd)
#    .     }
#    .     if (on_warning$silence) {
#    .         invokeRestart("muffleWarning")
#    .     }
#    . }, error = function (cnd)
#    . {
#    .     watcher$capture_plot_and_output()
#    .     cnd <- sanitize_call(cnd)
#    .     watcher$push(cnd)
#    .     switch(on_error, continue = invokeRestart("eval_continue"),
#    .         stop = invokeRestart("eval_stop"), error = NULL)
#    . })
# 213. withVisible(eval(expr, envir))
# 214. eval(expr, envir)
# 215. eval(expr, envir)
# 216. rmarkdown::render("county_broadband.rmd", "html_document")
# 217. knitr::knit(knit_input, knit_output, envir = envir, quiet = quiet)
# 218. process_file(text, output)
# 219. xfun:::handle_error(withCallingHandlers(if (tangle) process_tangle(group) else process_group(group),
#    .     error = function(e) {
#    .         if (progress && is.function(pb$interrupt))
#    .             pb$interrupt()
#    .         if (xfun::pkg_available("rlang", "1.0.0")) {
#    .             if (is_R_CMD_build() || is_R_CMD_check()) {
#    .                 cnd = tryCatch(rlang::entrace(e), error = identity)
#    .                 error <<- format(cnd)
#    .             }
#    .             else {
#    .                 rlang::entrace(e)
#    .             }
#    .         }
#    .     }), function(loc) {
#    .     setwd(wd)
#    .     write_utf8(res, output %n% stdout())
#    .     paste0("\nQuitting from ", loc, if (!is.null(error))
#    .         paste0("\n", rule(), error, "\n", rule()))
#    . }, if (labels[i] != "") sprintf(" [%s]", labels[i]), get_loc)
# 220. withCallingHandlers(if (tangle) process_tangle(group) else process_group(group),
#    .     error = function(e) {
#    .         if (progress && is.function(pb$interrupt))
#    .             pb$interrupt()
#    .         if (xfun::pkg_available("rlang", "1.0.0")) {
#    .             if (is_R_CMD_build() || is_R_CMD_check()) {
#    .                 cnd = tryCatch(rlang::entrace(e), error = identity)
#    .                 error <<- format(cnd)
#    .             }
#    .             else {
#    .                 rlang::entrace(e)
#    .             }
#    .         }
#    .     })
# 221. process_group(group)
# 222. call_block(x)
# 223. block_exec(params)
# 224. eng_r(options)
# 225. in_input_dir(evaluate(code, envir = env, new_device = FALSE,
#    .     keep_warning = if (is.numeric(options$warning)) TRUE else options$warning,
#    .     keep_message = if (is.numeric(options$message)) TRUE else options$message,
#    .     stop_on_error = if (is.numeric(options$error)) options$error else {
#    .         if (options$error && options$include)
#    .             0L
#    .         else 2L
#    .     }, output_handler = knit_handlers(options$render, options)))
# 226. in_dir(input_dir(), expr)
# 227. evaluate(code, envir = env, new_device = FALSE, keep_warning = if (is.numeric(options$warning)) TRUE else options$warning,
#    .     keep_message = if (is.numeric(options$message)) TRUE else options$message,
#    .     stop_on_error = if (is.numeric(options$error)) options$error else {
#    .         if (options$error && options$include)
#    .             0L
#    .         else 2L
#    .     }, output_handler = knit_handlers(options$render, options))
# 228. evaluate::evaluate(...)
# 229. withRestarts(with_handlers({
#    .     for (expr in tle$exprs) {
#    .         ev <- withVisible(eval(expr, envir))
#    .         watcher$capture_plot_and_output()
#    .         watcher$print_value(ev$value, ev$visible, envir)
#    .     }
#    .     TRUE
#    . }, handlers), eval_continue = function() TRUE, eval_stop = function() FALSE)
# 230. withRestartList(expr, restarts)
# 231. withOneRestart(withRestartList(expr, restarts[-nr]), restarts[[nr]])
# 232. doWithOneRestart(return(expr), restart)
# 233. withRestartList(expr, restarts[-nr])
# 234. withOneRestart(expr, restarts[[1L]])
# 235. doWithOneRestart(return(expr), restart)
# 236. with_handlers({
#    .     for (expr in tle$exprs) {
#    .         ev <- withVisible(eval(expr, envir))
#    .         watcher$capture_plot_and_output()
#    .         watcher$print_value(ev$value, ev$visible, envir)
#    .     }
#    .     TRUE
#    . }, handlers)
# 237. eval(call)
# 238. eval(call)
# 239. withCallingHandlers(code, message = function (cnd)
#    . {
#    .     watcher$capture_plot_and_output()
#    .     if (on_message$capture) {
#    .         watcher$push(cnd)
#    .     }
#    .     if (on_message$silence) {
#    .         invokeRestart("muffleMessage")
#    .     }
#    . }, warning = function (cnd)
#    . {
#    .     if (getOption("warn") >= 2 || getOption("warn") < 0) {
#    .         return()
#    .     }
#    .     watcher$capture_plot_and_output()
#    .     if (on_warning$capture) {
#    .         cnd <- sanitize_call(cnd)
#    .         watcher$push(cnd)
#    .     }
#    .     if (on_warning$silence) {
#    .         invokeRestart("muffleWarning")
#    .     }
#    . }, error = function (cnd)
#    . {
#    .     watcher$capture_plot_and_output()
#    .     cnd <- sanitize_call(cnd)
#    .     watcher$push(cnd)
#    .     switch(on_error, continue = invokeRestart("eval_continue"),
#    .         stop = invokeRestart("eval_stop"), error = NULL)
#    . })
# 240. withVisible(eval(expr, envir))
# 241. eval(expr, envir)
# 242. eval(expr, envir)
# 243. rmarkdown::render("county_broadband.rmd", "html_document")
# 244. knitr::knit(knit_input, knit_output, envir = envir, quiet = quiet)
# 245. process_file(text, output)
# 246. xfun:::handle_error(withCallingHandlers(if (tangle) process_tangle(group) else process_group(group),
#    .     error = function(e) {
#    .         if (progress && is.function(pb$interrupt))
#    .             pb$interrupt()
#    .         if (xfun::pkg_available("rlang", "1.0.0")) {
#    .             if (is_R_CMD_build() || is_R_CMD_check()) {
#    .                 cnd = tryCatch(rlang::entrace(e), error = identity)
#    .                 error <<- format(cnd)
#    .             }
#    .             else {
#    .                 rlang::entrace(e)
#    .             }
#    .         }
#    .     }), function(loc) {
#    .     setwd(wd)
#    .     write_utf8(res, output %n% stdout())
#    .     paste0("\nQuitting from ", loc, if (!is.null(error))
#    .         paste0("\n", rule(), error, "\n", rule()))
#    . }, if (labels[i] != "") sprintf(" [%s]", labels[i]), get_loc)
# 247. withCallingHandlers(if (tangle) process_tangle(group) else process_group(group),
#    .     error = function(e) {
#    .         if (progress && is.function(pb$interrupt))
#    .             pb$interrupt()
#    .         if (xfun::pkg_available("rlang", "1.0.0")) {
#    .             if (is_R_CMD_build() || is_R_CMD_check()) {
#    .                 cnd = tryCatch(rlang::entrace(e), error = identity)
#    .                 error <<- format(cnd)
#    .             }
#    .             else {
#    .                 rlang::entrace(e)
#    .             }
#    .         }
#    .     })
# 248. process_group(group)
# 249. call_block(x)
# 250. block_exec(params)
# 251. eng_r(options)
# 252. in_input_dir(evaluate(code, envir = env, new_device = FALSE,
#    .     keep_warning = if (is.numeric(options$warning)) TRUE else options$warning,
#    .     keep_message = if (is.numeric(options$message)) TRUE else options$message,
#    .     stop_on_error = if (is.numeric(options$error)) options$error else {
#    .         if (options$error && options$include)
#    .             0L
#    .         else 2L
#    .     }, output_handler = knit_handlers(options$render, options)))
# 253. in_dir(input_dir(), expr)
# 254. evaluate(code, envir = env, new_device = FALSE, keep_warning = if (is.numeric(options$warning)) TRUE else options$warning,
#    .     keep_message = if (is.numeric(options$message)) TRUE else options$message,
#    .     stop_on_error = if (is.numeric(options$error)) options$error else {
#    .         if (options$error && options$include)
#    .             0L
#    .         else 2L
#    .     }, output_handler = knit_handlers(options$render, options))
# 255. evaluate::evaluate(...)
# 256. withRestarts(with_handlers({
#    .     for (expr in tle$exprs) {
#    .         ev <- withVisible(eval(expr, envir))
#    .         watcher$capture_plot_and_output()
#    .         watcher$print_value(ev$value, ev$visible, envir)
#    .     }
#    .     TRUE
#    . }, handlers), eval_continue = function() TRUE, eval_stop = function() FALSE)
# 257. withRestartList(expr, restarts)
# 258. withOneRestart(withRestartList(expr, restarts[-nr]), restarts[[nr]])
# 259. doWithOneRestart(return(expr), restart)
# 260. withRestartList(expr, restarts[-nr])
# 261. withOneRestart(expr, restarts[[1L]])
# 262. doWithOneRestart(return(expr), restart)
# 263. with_handlers({
#    .     for (expr in tle$exprs) {
#    .         ev <- withVisible(eval(expr, envir))
#    .         watcher$capture_plot_and_output()
#    .         watcher$print_value(ev$value, ev$visible, envir)
#    .     }
#    .     TRUE
#    . }, handlers)
# 264. eval(call)
# 265. eval(call)
# 266. withCallingHandlers(code, message = function (cnd)
#    . {
#    .     watcher$capture_plot_and_output()
#    .     if (on_message$capture) {
#    .         watcher$push(cnd)
#    .     }
#    .     if (on_message$silence) {
#    .         invokeRestart("muffleMessage")
#    .     }
#    . }, warning = function (cnd)
#    . {
#    .     if (getOption("warn") >= 2 || getOption("warn") < 0) {
#    .         return()
#    .     }
#    .     watcher$capture_plot_and_output()
#    .     if (on_warning$capture) {
#    .         cnd <- sanitize_call(cnd)
#    .         watcher$push(cnd)
#    .     }
#    .     if (on_warning$silence) {
#    .         invokeRestart("muffleWarning")
#    .     }
#    . }, error = function (cnd)
#    . {
#    .     watcher$capture_plot_and_output()
#    .     cnd <- sanitize_call(cnd)
#    .     watcher$push(cnd)
#    .     switch(on_error, continue = invokeRestart("eval_continue"),
#    .         stop = invokeRestart("eval_stop"), error = NULL)
#    . })
# 267. withVisible(eval(expr, envir))
# 268. eval(expr, envir)
# 269. eval(expr, envir)
# 270. rmarkdown::render("county_broadband.rmd", "html_document")
# 271. knitr::knit(knit_input, knit_output, envir = envir, quiet = quiet)
# 272. process_file(text, output)
# 273. xfun:::handle_error(withCallingHandlers(if (tangle) process_tangle(group) else process_group(group),
#    .     error = function(e) {
#    .         if (progress && is.function(pb$interrupt))
#    .             pb$interrupt()
#    .         if (xfun::pkg_available("rlang", "1.0.0")) {
#    .             if (is_R_CMD_build() || is_R_CMD_check()) {
#    .                 cnd = tryCatch(rlang::entrace(e), error = identity)
#    .                 error <<- format(cnd)
#    .             }
#    .             else {
#    .                 rlang::entrace(e)
#    .             }
#    .         }
#    .     }), function(loc) {
#    .     setwd(wd)
#    .     write_utf8(res, output %n% stdout())
#    .     paste0("\nQuitting from ", loc, if (!is.null(error))
#    .         paste0("\n", rule(), error, "\n", rule()))
#    . }, if (labels[i] != "") sprintf(" [%s]", labels[i]), get_loc)
# 274. withCallingHandlers(if (tangle) process_tangle(group) else process_group(group),
#    .     error = function(e) {
#    .         if (progress && is.function(pb$interrupt))
#    .             pb$interrupt()
#    .         if (xfun::pkg_available("rlang", "1.0.0")) {
#    .             if (is_R_CMD_build() || is_R_CMD_check()) {
#    .                 cnd = tryCatch(rlang::entrace(e), error = identity)
#    .                 error <<- format(cnd)
#    .             }
#    .             else {
#    .                 rlang::entrace(e)
#    .             }
#    .         }
#    .     })
# 275. process_group(group)
# 276. call_block(x)
# 277. block_exec(params)
# 278. eng_r(options)
# 279. in_input_dir(evaluate(code, envir = env, new_device = FALSE,
#    .     keep_warning = if (is.numeric(options$warning)) TRUE else options$warning,
# ...
#  . }, if (labels[i] != "") sprintf(" [%s]", labels[i]), get_loc)
# 4. withCallingHandlers(if (tangle) process_tangle(group) else process_group(group),
#  .     error = function(e) {
#  .         if (progress && is.function(pb$interrupt))
#  .             pb$interrupt()
#  .         if (xfun::pkg_available("rlang", "1.0.0")) {
#  .             if (is_R_CMD_build() || is_R_CMD_check()) {
#  .                 cnd = tryCatch(rlang::entrace(e), error = identity)
#  .                 error <<- format(cnd)
#  .             }
#  .             else {
#  .                 rlang::entrace(e)
#  .             }
#  .         }
#  .     })
# 5. process_group(group)
# 6. call_block(x)
# 7. block_exec(params)
# 8. eng_r(options)
# 9. in_input_dir(evaluate(code, envir = env, new_device = FALSE,
#  .     keep_warning = if (is.numeric(options$warning)) TRUE else options$warning,
#  .     keep_message = if (is.numeric(options$message)) TRUE else options$message,
#  .     stop_on_error = if (is.numeric(options$error)) options$error else {
#  .         if (options$error && options$include)
#  .             0L
#  .         else 2L
#  .     }, output_handler = knit_handlers(options$render, options)))
# 10. in_dir(input_dir(), expr)
# 11. evaluate(code, envir = env, new_device = FALSE, keep_warning = if (is.numeric(options$warning)) TRUE else options$warning,
#   .     keep_message = if (is.numeric(options$message)) TRUE else options$message,
#   .     stop_on_error = if (is.numeric(options$error)) options$error else {
#   .         if (options$error && options$include)
#   .             0L
#   .         else 2L
#   .     }, output_handler = knit_handlers(options$render, options))
# 12. evaluate::evaluate(...)
# 13. withRestarts(with_handlers({
#   .     for (expr in tle$exprs) {
#   .         ev <- withVisible(eval(expr, envir))
#   .         watcher$capture_plot_and_output()
#   .         watcher$print_value(ev$value, ev$visible, envir)
#   .     }
#   .     TRUE
#   . }, handlers), eval_continue = function() TRUE, eval_stop = function() FALSE)
# 14. withRestartList(expr, restarts)
# 15. withOneRestart(withRestartList(expr, restarts[-nr]), restarts[[nr]])
# 16. doWithOneRestart(return(expr), restart)
# 17. withRestartList(expr, restarts[-nr])
# 18. withOneRestart(expr, restarts[[1L]])
# 19. doWithOneRestart(return(expr), restart)
# 20. with_handlers({
#   .     for (expr in tle$exprs) {
#   .         ev <- withVisible(eval(expr, envir))
#   .         watcher$capture_plot_and_output()
#   .         watcher$print_value(ev$value, ev$visible, envir)
#   .     }
#   .     TRUE
#   . }, handlers)
# 21. eval(call)
# 22. eval(call)
# 23. withCallingHandlers(code, message = function (cnd)
#   . {
#   .     watcher$capture_plot_and_output()
#   .     if (on_message$capture) {
#   .         watcher$push(cnd)
#   .     }
#   .     if (on_message$silence) {
#   .         invokeRestart("muffleMessage")
#   .     }
#   . }, warning = function (cnd)
#   . {
#   .     if (getOption("warn") >= 2 || getOption("warn") < 0) {
#   .         return()
#   .     }
#   .     watcher$capture_plot_and_output()
#   .     if (on_warning$capture) {
#   .         cnd <- sanitize_call(cnd)
#   .         watcher$push(cnd)
#   .     }
#   .     if (on_warning$silence) {
#   .         invokeRestart("muffleWarning")
#   .     }
#   . }, error = function (cnd)
#   . {
#   .     watcher$capture_plot_and_output()
#   .     cnd <- sanitize_call(cnd)
#   .     watcher$push(cnd)
#   .     switch(on_error, continue = invokeRestart("eval_continue"),
#   .         stop = invokeRestart("eval_stop"), error = NULL)
#   . })
# 24. withVisible(eval(expr, envir))
# 25. eval(expr, envir)
# 26. eval(expr, envir)
# 27. rmarkdown::render("county_broadband.rmd", "html_document")
# 28. knitr::knit(knit_input, knit_output, envir = envir, quiet = quiet)
# 29. process_file(text, output)
# 30. xfun:::handle_error(withCallingHandlers(if (tangle) process_tangle(group) else process_group(group),
#   .     error = function(e) {
#   .         if (progress && is.function(pb$interrupt))
#   .             pb$interrupt()
#   .         if (xfun::pkg_available("rlang", "1.0.0")) {
#   .             if (is_R_CMD_build() || is_R_CMD_check()) {
#   .                 cnd = tryCatch(rlang::entrace(e), error = identity)
#   .                 error <<- format(cnd)
#   .             }
#   .             else {
#   .                 rlang::entrace(e)
#   .             }
#   .         }
#   .     }), function(loc) {
#   .     setwd(wd)
#   .     write_utf8(res, output %n% stdout())
#   .     paste0("\nQuitting from ", loc, if (!is.null(error))
#   .         paste0("\n", rule(), error, "\n", rule()))
#   . }, if (labels[i] != "") sprintf(" [%s]", labels[i]), get_loc)
# 31. withCallingHandlers(if (tangle) process_tangle(group) else process_group(group),
#   .     error = function(e) {
#   .         if (progress && is.function(pb$interrupt))
#   .             pb$interrupt()
#   .         if (xfun::pkg_available("rlang", "1.0.0")) {
#   .             if (is_R_CMD_build() || is_R_CMD_check()) {
#   .                 cnd = tryCatch(rlang::entrace(e), error = identity)
#   .                 error <<- format(cnd)
#   .             }
#   .             else {
#   .                 rlang::entrace(e)
#   .             }
#   .         }
#   .     })
# 32. process_group(group)
# 33. call_block(x)
# 34. block_exec(params)
# 35. eng_r(options)
# 36. in_input_dir(evaluate(code, envir = env, new_device = FALSE,
#   .     keep_warning = if (is.numeric(options$warning)) TRUE else options$warning,
#   .     keep_message = if (is.numeric(options$message)) TRUE else options$message,
#   .     stop_on_error = if (is.numeric(options$error)) options$error else {
#   .         if (options$error && options$include)
#   .             0L
#   .         else 2L
#   .     }, output_handler = knit_handlers(options$render, options)))
# 37. in_dir(input_dir(), expr)
# 38. evaluate(code, envir = env, new_device = FALSE, keep_warning = if (is.numeric(options$warning)) TRUE else options$warning,
#   .     keep_message = if (is.numeric(options$message)) TRUE else options$message,
#   .     stop_on_error = if (is.numeric(options$error)) options$error else {
#   .         if (options$error && options$include)
#   .             0L
#   .         else 2L
#   .     }, output_handler = knit_handlers(options$render, options))
# 39. evaluate::evaluate(...)
# 40. withRestarts(with_handlers({
#   .     for (expr in tle$exprs) {
#   .         ev <- withVisible(eval(expr, envir))
#   .         watcher$capture_plot_and_output()
#   .         watcher$print_value(ev$value, ev$visible, envir)
#   .     }
#   .     TRUE
#   . }, handlers), eval_continue = function() TRUE, eval_stop = function() FALSE)
# 41. withRestartList(expr, restarts)
# 42. withOneRestart(withRestartList(expr, restarts[-nr]), restarts[[nr]])
# 43. doWithOneRestart(return(expr), restart)
# 44. withRestartList(expr, restarts[-nr])
# 45. withOneRestart(expr, restarts[[1L]])
# 46. doWithOneRestart(return(expr), restart)
# 47. with_handlers({
#   .     for (expr in tle$exprs) {
#   .         ev <- withVisible(eval(expr, envir))
#   .         watcher$capture_plot_and_output()
#   .         watcher$print_value(ev$value, ev$visible, envir)
#   .     }
#   .     TRUE
#   . }, handlers)
# 48. eval(call)
# 49. eval(call)
# 50. withCallingHandlers(code, message = function (cnd)
#   . {
#   .     watcher$capture_plot_and_output()
#   .     if (on_message$capture) {
#   .         watcher$push(cnd)
#   .     }
#   .     if (on_message$silence) {
#   .         invokeRestart("muffleMessage")
#   .     }
#   . }, warning = function (cnd)
#   . {
#   .     if (getOption("warn") >= 2 || getOption("warn") < 0) {
#   .         return()
#   .     }
#   .     watcher$capture_plot_and_output()
#   .     if (on_warning$capture) {
#   .         cnd <- sanitize_call(cnd)
#   .         watcher$push(cnd)
#   .     }
#   .     if (on_warning$silence) {
#   .         invokeRestart("muffleWarning")
#   .     }
#   . }, error = function (cnd)
#   . {
#   .     watcher$capture_plot_and_output()
#   .     cnd <- sanitize_call(cnd)
#   .     watcher$push(cnd)
#   .     switch(on_error, continue = invokeRestart("eval_continue"),
#   .         stop = invokeRestart("eval_stop"), error = NULL)
#   . })
# 51. withVisible(eval(expr, envir))
# 52. eval(expr, envir)
# 53. eval(expr, envir)
# 54. rmarkdown::render("county_broadband.rmd", "html_document")
# 55. convert(output_file, run_citeproc)
# 56. convert_it(output)
# 57. convert_fun(output = output, input_files, pandoc_to, output_format$pandoc$from,
#   .     citeproc, pandoc_args, !quiet)
# 58. stop2("pandoc document conversion failed with error ", result)
# 59. stop(..., call. = FALSE)
# 60. .handleSimpleError(function (e)
#   . {
#   .     if (progress && is.function(pb$interrupt))
#   .         pb$interrupt()
#   .     if (xfun::pkg_available("rlang", "1.0.0")) {
#   .         if (is_R_CMD_build() || is_R_CMD_check()) {
#   .             cnd = tryCatch(rlang::entrace(e), error = identity)
#   .             error <<- format(cnd)
#   .         }
#   .         else {
#   .             rlang::entrace(e)
#   .         }
#   .     }
#   . }, "pandoc document conversion failed with error 99", base::quote(NULL))
# 61. h(simpleError(msg, call))
# 62. rlang::entrace(e)
# 63. cnd_signal(entraced)
# 64. signal_abort(cnd)
# 65. signalCondition(cnd)
# Error:
# ! pandoc document conversion failed with error 99
# Traceback:
#
# 1. knitr::knit(knit_input, knit_output, envir = envir, quiet = quiet)
# 2. process_file(text, output)
# 3. xfun:::handle_error(withCallingHandlers(if (tangle) process_tangle(group) else process_group(group),
#  .     error = function(e) {
#  .         if (progress && is.function(pb$interrupt))
#  .             pb$interrupt()
#  .         if (xfun::pkg_available("rlang", "1.0.0")) {
#  .             if (is_R_CMD_build() || is_R_CMD_check()) {
#  .                 cnd = tryCatch(rlang::entrace(e), error = identity)
#  .                 error <<- format(cnd)
#  .             }
#  .             else {
#  .                 rlang::entrace(e)
#  .             }
#  .         }
#  .     }), function(loc) {
#  .     setwd(wd)
#  .     write_utf8(res, output %n% stdout())
#  .     paste0("\nQuitting from ", loc, if (!is.null(error))
#  .         paste0("\n", rule(), error, "\n", rule()))
#  . }, if (labels[i] != "") sprintf(" [%s]", labels[i]), get_loc)
# 4. withCallingHandlers(if (tangle) process_tangle(group) else process_group(group),
#  .     error = function(e) {
#  .         if (progress && is.function(pb$interrupt))
#  .             pb$interrupt()
#  .         if (xfun::pkg_available("rlang", "1.0.0")) {
#  .             if (is_R_CMD_build() || is_R_CMD_check()) {
#  .                 cnd = tryCatch(rlang::entrace(e), error = identity)
#  .                 error <<- format(cnd)
#  .             }
#  .             else {
#  .                 rlang::entrace(e)
#  .             }
#  .         }
#  .     })
# 5. process_group(group)
# 6. call_block(x)
# 7. block_exec(params)
# 8. eng_r(options)
# 9. in_input_dir(evaluate(code, envir = env, new_device = FALSE,
#  .     keep_warning = if (is.numeric(options$warning)) TRUE else options$warning,
#  .     keep_message = if (is.numeric(options$message)) TRUE else options$message,
#  .     stop_on_error = if (is.numeric(options$error)) options$error else {
#  .         if (options$error && options$include)
#  .             0L
#  .         else 2L
#  .     }, output_handler = knit_handlers(options$render, options)))
# 10. in_dir(input_dir(), expr)
# 11. evaluate(code, envir = env, new_device = FALSE, keep_warning = if (is.numeric(options$warning)) TRUE else options$warning,
#   .     keep_message = if (is.numeric(options$message)) TRUE else options$message,
#   .     stop_on_error = if (is.numeric(options$error)) options$error else {
#   .         if (options$error && options$include)
#   .             0L
#   .         else 2L
#   .     }, output_handler = knit_handlers(options$render, options))
# 12. evaluate::evaluate(...)
# 13. withRestarts(with_handlers({
#   .     for (expr in tle$exprs) {
#   .         ev <- withVisible(eval(expr, envir))
#   .         watcher$capture_plot_and_output()
#   .         watcher$print_value(ev$value, ev$visible, envir)
#   .     }
#   .     TRUE
#   . }, handlers), eval_continue = function() TRUE, eval_stop = function() FALSE)
# 14. withRestartList(expr, restarts)
# 15. withOneRestart(withRestartList(expr, restarts[-nr]), restarts[[nr]])
# 16. doWithOneRestart(return(expr), restart)
# 17. withRestartList(expr, restarts[-nr])
# 18. withOneRestart(expr, restarts[[1L]])
# 19. doWithOneRestart(return(expr), restart)
# 20. with_handlers({
#   .     for (expr in tle$exprs) {
#   .         ev <- withVisible(eval(expr, envir))
#   .         watcher$capture_plot_and_output()
#   .         watcher$print_value(ev$value, ev$visible, envir)
#   .     }
#   .     TRUE
#   . }, handlers)
# 21. eval(call)
# 22. eval(call)
# 23. withCallingHandlers(code, message = function (cnd)
#   . {
#   .     watcher$capture_plot_and_output()
#   .     if (on_message$capture) {
#   .         watcher$push(cnd)
#   .     }
#   .     if (on_message$silence) {
#   .         invokeRestart("muffleMessage")
#   .     }
#   . }, warning = function (cnd)
#   . {
#   .     if (getOption("warn") >= 2 || getOption("warn") < 0) {
#   .         return()
#   .     }
#   .     watcher$capture_plot_and_output()
#   .     if (on_warning$capture) {
#   .         cnd <- sanitize_call(cnd)
#   .         watcher$push(cnd)
#   .     }
#   .     if (on_warning$silence) {
#   .         invokeRestart("muffleWarning")
#   .     }
#   . }, error = function (cnd)
#   . {
#   .     watcher$capture_plot_and_output()
#   .     cnd <- sanitize_call(cnd)
#   .     watcher$push(cnd)
#   .     switch(on_error, continue = invokeRestart("eval_continue"),
#   .         stop = invokeRestart("eval_stop"), error = NULL)
#   . })
# 24. withVisible(eval(expr, envir))
# 25. eval(expr, envir)
# 26. eval(expr, envir)
# 27. rmarkdown::render("county_broadband.rmd", "html_document")
# 28. convert(output_file, run_citeproc)
# 29. convert_it(output)
# 30. convert_fun(output = output, input_files, pandoc_to, output_format$pandoc$from,
#   .     citeproc, pandoc_args, !quiet)
# 31. stop2("pandoc document conversion failed with error ", result)
# 32. stop(..., call. = FALSE)
# 33. .handleSimpleError(function (e)
#   . {
#   .     if (progress && is.function(pb$interrupt))
#   .         pb$interrupt()
#   .     if (xfun::pkg_available("rlang", "1.0.0")) {
#   .         if (is_R_CMD_build() || is_R_CMD_check()) {
#   .             cnd = tryCatch(rlang::entrace(e), error = identity)
#   .             error <<- format(cnd)
#   .         }
#   .         else {
#   .             rlang::entrace(e)
#   .         }
#   .     }
#   . }, "pandoc document conversion failed with error 99", base::quote(NULL))
# 34. h(simpleError(msg, call))
# 35. rlang::entrace(e)
# 36. cnd_signal(entraced)
# 37. signal_abort(cnd)
# 38. signalCondition(cnd)
# 19/19
# output file: county_broadband.knit.md
# /Users/benemery/miniforge3/envs/r/bin/pandoc +RTS -K512m -RTS county_broadband.knit.md --to html4 --from markdown+autolink_bare_uris+tex_math_single_backslash --output county_broadband.html --lua-filter /Users/benemery/miniforge3/envs/r/lib/R/library/rmarkdown/rmarkdown/lua/pagebreak.lua --lua-filter /Users/benemery/miniforge3/envs/r/lib/R/library/rmarkdown/rmarkdown/lua/latex-div.lua --self-contained --variable bs3=TRUE --section-divs --template /Users/benemery/miniforge3/envs/r/lib/R/library/rmarkdown/rmd/h/default.html --no-highlight --variable highlightjs=1 --variable theme=bootstrap --mathjax --variable 'mathjax-url=https://mathjax.rstudio.com/latest/MathJax.js?config=TeX-AMS-MML_HTMLorMML' --include-in-header /var/folders/hm/ck7xwlk95kz6g9s23gwq0x_r0000gn/T//Rtmp3OgH9j/rmarkdown-str128db1d78e3eb.html
# Error: pandoc document conversion failed with error 99
# Traceback:
#
# 1. convert(output_file, run_citeproc)
# 2. convert_it(output)
# 3. convert_fun(output = output, input_files, pandoc_to, output_format$pandoc$from,
#  .     citeproc, pandoc_args, !quiet)
# 4. stop2("pandoc document conversion failed with error ", result)
# 5. stop(..., call. = FALSE)
# 6. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "pandoc document conversion failed with error 99", base::quote(NULL))
